# %%
import pandas as pd
import json
import re
import nltk
import string

# %%
# load data using Python JSON module
with open('NLP-test-modified.json','r') as f:
    data = json.loads(f.read())

# %%
# Normalizing data
df = pd.json_normalize(data['hits']['hit'])
df.columns = df.columns.str.replace('_source.', '')

continuous_list = ['headline','searchabletext','abstract','fulltext','prospectkeyword']
categorical_list = ['programname','sourcename','mediatype','commentator','articletype',
                    'sourcesystem','country','entityname','companyname','deliverysetname','briefname']


df = df[continuous_list + categorical_list]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   headline         300 non-null    object
#  1   searchabletext   300 non-null    object
#  2   abstract         300 non-null    object
#  3   fulltext         158 non-null    object
#  4   prospectkeyword  298 non-null    object
#  5   programname      300 non-null    object
#  6   sourcename       300 non-null    object
#  7   mediatype        300 non-null    object
#  8   commentator      300 non-null    object
#  9   articletype      284 non-null    object
#  10  sourcesystem     300 non-null    object
#  11  country          300 non-null    object
#  12  entityname       186 non-null    object
#  13  companyname      300 non-null    object
#  14  deliverysetname  300 non-null    object
#  15  briefname        300 non-null    object
# dtypes: object(16)
# ...

# %%
df.drop(['fulltext','entityname'], axis = 1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   headline         300 non-null    object
#  1   searchabletext   300 non-null    object
#  2   abstract         300 non-null    object
#  3   prospectkeyword  298 non-null    object
#  4   programname      300 non-null    object
#  5   sourcename       300 non-null    object
#  6   mediatype        300 non-null    object
#  7   commentator      300 non-null    object
#  8   articletype      284 non-null    object
#  9   sourcesystem     300 non-null    object
#  10  country          300 non-null    object
#  11  companyname      300 non-null    object
#  12  deliverysetname  300 non-null    object
#  13  briefname        300 non-null    object
# dtypes: object(14)
# memory usage: 32.9+ KB

# %%
import xml.etree.ElementTree as ET
import xmltodict

# %%
for x in df.searchabletext:
    data = xmltodict.parse(x)
    print(data['root']['item']['full']['#text'])
    print("=====================================")
# Out:
# Taiwanese regional budget carrierV Air will go out of business in October after less than two years of operation because of competition and low passenger loads, pointing to saturation in its homeland's discount aviation market, airline officials and analysts said.
#
#     V Air's parent company TransAsia Airways said on 9 August it would stop all routes by the discount carrier that launched in December 2014 as Taiwan's first locally owned budget airline, TransAsia will pick up two of V Air's seven routes and try to rehire some of its 200 staff people, the company's marketing vice president Chen Yi-Chieh told Asian Aviation, "In 2014, the environment for low-cost carriers wasn't quite the same," Chen said, JJThere weren't so many brands in the market then.
#
#     So the industry has changed a lot."
#
# ...

# %%
def parse_xml(xml):
    data = xmltodict.parse(xml)
    print(data)
    print("===============================================================")
    return data['root']['item']['full']['#text']

df['newfulltext'] = df['searchabletext'].apply(parse_xml)
# Out:
# OrderedDict([('root', OrderedDict([('item', OrderedDict([('id', OrderedDict([('@xml:lang', 'en-US'), ('#text', '649151843')])), ('head', OrderedDict([('@xml:lang', 'en-US'), ('#text', "Taiwan's budget carrier V Air to cease operations")])), ('abs', OrderedDict([('@xml:lang', 'en-US'), ('#text', 'Taiwanese regional budget carrierV Air will go out of business in October after less than two years of operation because of competition and low passenger loads, pointing to saturation in its homeland\'s discount aviation market, airline officials and analysts said. V Air\'s parent company TransAsia Airways said on 9 August it would stop all routes by the discount carrier that launched in December 2014 as Taiwan\'s first locally owned budget airline, TransAsia will pick up two of V Air\'s seven routes and try to rehire some of its 200 staff people, the company\'s marketing vice president Chen Yi-Chieh told Asian Aviation, "In 2014, the environment for low-cost carriers wasn\'t quite the same,"
# ...

# %%
searchabletexts = df['searchabletext'].tolist()
searchabletexts[:1]

# %%
punct = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{}~'   # `|` is not present here
transtab = str.maketrans(dict.fromkeys(punct, ''))

df['searchabletext'] = df['searchabletext'].str.translate(transtab)

# %%
searchabletexts = df['searchabletext'].tolist()
searchabletexts[:1]

# %%
words =[
    word \
    for searchabletext in searchabletexts \
    for word in searchabletext_tokenizer(searchabletext)
]
stemmer = nltk.stem.snowball.SnowballStemmer('english')
stems = (stemmer.stem(word) for word in words)

word_for_stem = \
    pd.DataFrame({ 'stem': stems, 'word': words }) \
    .set_index('stem') \
    .sort_index()
word_for_stem = word_for_stem.loc[~word_for_stem.index.duplicated(keep='first')]
word_for_stem.head()

# %%
for col in df[categorical_list].columns:
    display(df[col].value_counts().to_frame())
